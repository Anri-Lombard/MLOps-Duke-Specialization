# %%
# !pip install azureml-opendatasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting azureml-opendatasets
#   Downloading azureml_opendatasets-1.51.0-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 55.2 MB/s eta 0:00:00
# Collecting azureml-telemetry~=1.51.0 (from azureml-opendatasets)
#   Downloading azureml_telemetry-1.51.0-py3-none-any.whl (30 kB)
# Collecting azureml-core~=1.51.0 (from azureml-opendatasets)
#   Downloading azureml_core-1.51.0.post1-py3-none-any.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 82.5 MB/s eta 0:00:00
# Collecting azureml-dataset-runtime[fuse,pandas]~=1.51.0 (from azureml-opendatasets)
#   Downloading azureml_dataset_runtime-1.51.0-py3-none-any.whl (2.3 kB)
# Requirement already satisfied: numpy<=2.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from azureml-opendatasets) (1.22.4)
# Requirement already satisfied: pandas<=2.0.0,>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from azureml-opendatasets) (1.5.3)
# Requirement already satisfied: scipy<=2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from azureml-opendatasets) (1.10.1)
# Requirement already satisfied: pyarrow>=0.16.0 in /usr/local/lib/python3.10/dist-packages (from azureml-opendatasets) (9.0.0)
# Collecting pyspark (from azureml-opendatasets)
#   Downloading pyspark-3.4.0.tar.gz (310.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from azureml-core~=1.51.0->azureml-opendatasets) (2022.7.1)
# Collecting backports.tempfile (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting pathspec<1.0.0 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading pathspec-0.11.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: requests[socks]<3.0.0,>=2.19.1 in /usr/local/lib/python3.10/dist-packages (from azureml-core~=1.51.0->azureml-opendatasets) (2.27.1)
# Collecting msal<2.0.0,>=1.15.0 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading msal-1.22.0-py2.py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 9.1 MB/s eta 0:00:00
# Collecting msal-extensions<=1.0.0,>=0.3.0 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading msal_extensions-1.0.0-py2.py3-none-any.whl (19 kB)
# Collecting knack~=0.10.0 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading knack-0.10.1-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 7.4 MB/s eta 0:00:00
# Collecting azure-core<2.0.0 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading azure_core-1.27.1-py3-none-any.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.5/174.5 kB 20.8 MB/s eta 0:00:00
# Collecting pkginfo (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading pkginfo-1.9.6-py3-none-any.whl (30 kB)
# Collecting argcomplete<3 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading argcomplete-2.1.2-py3-none-any.whl (37 kB)
# Collecting humanfriendly<11.0,>=4.7 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.7 MB/s eta 0:00:00
# Collecting paramiko<4.0.0,>=2.0.8 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading paramiko-3.2.0-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.2/224.2 kB 26.3 MB/s eta 0:00:00
# Collecting azure-mgmt-resource<=22.0.0,>=15.0.0 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading azure_mgmt_resource-22.0.0-py3-none-any.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 90.1 MB/s eta 0:00:00
# Collecting azure-mgmt-containerregistry<11,>=8.2.0 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading azure_mgmt_containerregistry-10.1.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 81.7 MB/s eta 0:00:00
# Collecting azure-mgmt-storage<=21.0.0,>=16.0.0 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading azure_mgmt_storage-21.0.0-py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 99.5 MB/s eta 0:00:00
# Collecting azure-mgmt-keyvault<11.0.0,>=0.40.0 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading azure_mgmt_keyvault-10.2.2-py3-none-any.whl (780 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.2/780.2 kB 61.1 MB/s eta 0:00:00
# Collecting azure-mgmt-authorization<4,>=0.40.0 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading azure_mgmt_authorization-3.0.0-py3-none-any.whl (965 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.9/965.9 kB 63.1 MB/s eta 0:00:00
# Collecting azure-graphrbac<1.0.0,>=0.40.0 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.4/141.4 kB 18.3 MB/s eta 0:00:00
# Collecting azure-common<2.0.0,>=1.1.12 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Collecting msrest<=0.7.1,>=0.5.1 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 9.8 MB/s eta 0:00:00
# Collecting msrestazure<=0.6.4,>=0.4.33 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<2.0.0,>=1.23 in /usr/local/lib/python3.10/dist-packages (from azureml-core~=1.51.0->azureml-opendatasets) (1.26.15)
# Collecting packaging<=23.0,>=20.0 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading packaging-23.0-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 4.2 MB/s eta 0:00:00
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,>=41 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading cryptography-41.0.1-cp37-abi3-manylinux_2_28_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 67.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /usr/local/lib/python3.10/dist-packages (from azureml-core~=1.51.0->azureml-opendatasets) (2.8.2)
# Collecting ndg-httpsclient<=0.5.1 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting SecretStorage<4.0.0 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Requirement already satisfied: jsonpickle<4.0.0 in /usr/local/lib/python3.10/dist-packages (from azureml-core~=1.51.0->azureml-opendatasets) (3.0.1)
# Requirement already satisfied: contextlib2<22.0.0 in /usr/local/lib/python3.10/dist-packages (from azureml-core~=1.51.0->azureml-opendatasets) (0.6.0.post1)
# Collecting docker<7.0.0 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading docker-6.1.3-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 15.0 MB/s eta 0:00:00
# Collecting PyJWT<3.0.0 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading PyJWT-2.7.0-py3-none-any.whl (22 kB)
# Collecting adal<=1.2.7,>=1.2.0 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 6.9 MB/s eta 0:00:00
# Collecting pyopenssl<24.0.0 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading pyOpenSSL-23.2.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 3.0 MB/s eta 0:00:00
# Collecting jmespath<2.0.0 (from azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting azureml-dataprep<4.11.0a,>=4.10.0a (from azureml-dataset-runtime[fuse,pandas]~=1.51.0->azureml-opendatasets)
#   Downloading azureml_dataprep-4.10.8-py3-none-any.whl (38.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 11.3 MB/s eta 0:00:00
# Collecting fusepy<4.0.0,>=3.0.1 (from azureml-dataset-runtime[fuse,pandas]~=1.51.0->azureml-opendatasets)
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting applicationinsights (from azureml-telemetry~=1.51.0->azureml-opendatasets)
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark->azureml-opendatasets) (0.10.9.7)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0->azureml-core~=1.51.0->azureml-opendatasets) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0->azureml-core~=1.51.0->azureml-opendatasets) (4.5.0)
# Collecting azure-mgmt-core<2.0.0,>=1.3.2 (from azure-mgmt-authorization<4,>=0.40.0->azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading azure_mgmt_core-1.4.0-py3-none-any.whl (27 kB)
# Collecting isodate<1.0.0,>=0.6.1 (from azure-mgmt-keyvault<11.0.0,>=0.40.0->azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 5.1 MB/s eta 0:00:00
# Collecting dotnetcore2<4.0.0,>=3.0.0 (from azureml-dataprep<4.11.0a,>=4.10.0a->azureml-dataset-runtime[fuse,pandas]~=1.51.0->azureml-opendatasets)
#   Downloading dotnetcore2-3.1.23-py3-none-manylinux1_x86_64.whl (31.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.1/31.1 MB 44.7 MB/s eta 0:00:00
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0 (from azureml-dataprep<4.11.0a,>=4.10.0a->azureml-dataset-runtime[fuse,pandas]~=1.51.0->azureml-opendatasets)
#   Downloading azureml_dataprep_native-38.0.0-cp310-cp310-manylinux1_x86_64.whl (191 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.7/191.7 kB 19.6 MB/s eta 0:00:00
# Collecting azureml-dataprep-rslex~=2.17.12dev0 (from azureml-dataprep<4.11.0a,>=4.10.0a->azureml-dataset-runtime[fuse,pandas]~=1.51.0->azureml-opendatasets)
#   Downloading azureml_dataprep_rslex-2.17.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 65.4 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle<3.0.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from azureml-dataprep<4.11.0a,>=4.10.0a->azureml-dataset-runtime[fuse,pandas]~=1.51.0->azureml-opendatasets) (2.2.1)
# Collecting azure-identity>=1.7.0 (from azureml-dataprep<4.11.0a,>=4.10.0a->azureml-dataset-runtime[fuse,pandas]~=1.51.0->azureml-opendatasets)
#   Downloading azure_identity-1.13.0-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.6/151.6 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from azureml-dataprep<4.11.0a,>=4.10.0a->azureml-dataset-runtime[fuse,pandas]~=1.51.0->azureml-opendatasets) (4.3.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from azureml-dataprep<4.11.0a,>=4.10.0a->azureml-dataset-runtime[fuse,pandas]~=1.51.0->azureml-opendatasets) (6.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,>=41->azureml-core~=1.51.0->azureml-opendatasets) (1.15.1)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from docker<7.0.0->azureml-core~=1.51.0->azureml-opendatasets) (1.5.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from knack~=0.10.0->azureml-core~=1.51.0->azureml-opendatasets) (2.14.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from knack~=0.10.0->azureml-core~=1.51.0->azureml-opendatasets) (0.8.10)
# Collecting portalocker<3,>=1.0 (from msal-extensions<=1.0.0,>=0.3.0->azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.51.0->azureml-opendatasets) (2022.12.7)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.51.0->azureml-opendatasets) (1.3.1)
# Requirement already satisfied: pyasn1>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ndg-httpsclient<=0.5.1->azureml-core~=1.51.0->azureml-opendatasets) (0.5.0)
# Collecting bcrypt>=3.2 (from paramiko<4.0.0,>=2.0.8->azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading bcrypt-4.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (593 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.7/593.7 kB 41.9 MB/s eta 0:00:00
# Collecting pynacl>=1.5 (from paramiko<4.0.0,>=2.0.8->azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 62.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.51.0->azureml-opendatasets) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.51.0->azureml-opendatasets) (3.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.51.0->azureml-opendatasets) (1.7.1)
# Collecting jeepney>=0.6 (from SecretStorage<4.0.0->azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading jeepney-0.8.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 5.6 MB/s eta 0:00:00
# Collecting backports.weakref (from backports.tempfile->azureml-core~=1.51.0->azureml-opendatasets)
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,>=41->azureml-core~=1.51.0->azureml-opendatasets) (2.21)
# Collecting distro>=1.2.0 (from dotnetcore2<4.0.0,>=3.0.0->azureml-dataprep<4.11.0a,>=4.10.0a->azureml-dataset-runtime[fuse,pandas]~=1.51.0->azureml-opendatasets)
#   Downloading distro-1.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.5.0->msrest<=0.7.1,>=0.5.1->azureml-core~=1.51.0->azureml-opendatasets) (3.2.2)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->azureml-dataprep<4.11.0a,>=4.10.0a->azureml-dataset-runtime[fuse,pandas]~=1.51.0->azureml-opendatasets) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->azureml-dataprep<4.11.0a,>=4.10.0a->azureml-dataset-runtime[fuse,pandas]~=1.51.0->azureml-opendatasets) (0.19.3)
# Building wheels for collected packages: pyspark, fusepy
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.4.0-py2.py3-none-any.whl size=311317130 sha256=030dc9514ec5c52dfc53f771f71977453cc936cc2478fdff53c68286c8215d67
#   Stored in directory: /root/.cache/pip/wheels/7b/1b/4b/3363a1d04368e7ff0d408e57ff57966fcdf00583774e761327
#   Building wheel for fusepy (setup.py) ... done
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10486 sha256=49ff799953206a89451a4c7e19342b60fe3741943f89a0b0451206e1cebadf52
#   Stored in directory: /root/.cache/pip/wheels/c0/18/f6/f0d6be9d0435e2677ce5cc758e91da50053dce456a346f08c5
# Successfully built pyspark fusepy
# Installing collected packages: fusepy, backports.weakref, azureml-dataprep-rslex, azureml-dataprep-native, azure-common, applicationinsights, pyspark, PyJWT, portalocker, pkginfo, pathspec, packaging, jmespath, jeepney, isodate, humanfriendly, distro, bcrypt, backports.tempfile, argcomplete, pynacl, knack, dotnetcore2, docker, cryptography, azure-core, SecretStorage, pyopenssl, paramiko, msrest, azure-mgmt-core, adal, ndg-httpsclient, msrestazure, msal, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, msal-extensions, azure-graphrbac, azureml-core, azure-identity, azureml-telemetry, azureml-dataprep, azureml-dataset-runtime, azureml-opendatasets
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.1
#     Uninstalling packaging-23.1:
#       Successfully uninstalled packaging-23.1
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 40.0.2
#     Uninstalling cryptography-40.0.2:
#       Successfully uninstalled cryptography-40.0.2
# Successfully installed PyJWT-2.7.0 SecretStorage-3.3.3 adal-1.2.7 applicationinsights-0.11.10 argcomplete-2.1.2 azure-common-1.1.28 azure-core-1.27.1 azure-graphrbac-0.61.1 azure-identity-1.13.0 azure-mgmt-authorization-3.0.0 azure-mgmt-containerregistry-10.1.0 azure-mgmt-core-1.4.0 azure-mgmt-keyvault-10.2.2 azure-mgmt-resource-22.0.0 azure-mgmt-storage-21.0.0 azureml-core-1.51.0.post1 azureml-dataprep-4.10.8 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-2.17.12 azureml-dataset-runtime-1.51.0 azureml-opendatasets-1.51.0 azureml-telemetry-1.51.0 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-4.0.1 cryptography-41.0.1 distro-1.8.0 docker-6.1.3 dotnetcore2-3.1.23 fusepy-3.0.1 humanfriendly-10.0 isodate-0.6.1 jeepney-0.8.0 jmespath-1.0.1 knack-0.10.1 msal-1.22.0 msal-extensions-1.0.0 msrest-0.7.1 msrestazure-0.6.4 ndg-httpsclient-0.5.1 packaging-23.0 paramiko-3.2.0 pathspec-0.11.1 pkginfo-1.9.6 portalocker-2.7.0 pynacl-1.5.0 pyopenssl-23.2.0 pyspark-3.4.0

# %%
from azureml.opendatasets import PublicHolidays

from datetime import datetime
from dateutil import parser
from dateutil.relativedelta import relativedelta


today = datetime.today()
last_year = datetime.today() - relativedelta(months=12)
hol = PublicHolidays(start_date=last_year, end_date=today)
hol_df = hol.to_pandas_dataframe()
# Out:
# [Info] read from /tmp/tmpwzzotvck/https%3A/%2Fazureopendatastorage.azurefd.net/holidaydatacontainer/Processed/part-00000-tid-8468414522853579044-35925ba8-a227-4b80-9c89-17065e7bf1db-649-c000.snappy.parquet

# %%
hol_df.head()
# Out:
#       countryOrRegion                                        holidayName  \
# 27368          Norway                                             Søndag
# 27369          Sweden                                             Söndag
# 27370       Argentina  Día Pase a la Inmortalidad del General D. Manu...
# 27371        Colombia          Corpus Christi [Corpus Christi](Observed)
# 27372         Croatia                           Dan antifašističke borbe
#
#                                     normalizeHolidayName isPaidTimeOff  \
# 27368                                             Søndag          None
# 27369                                             Söndag          None
# 27370  Día Pase a la Inmortalidad del General D. Manu...          None
# 27371                    Corpus Christi [Corpus Christi]          None
# 27372                           Dan antifašističke borbe          None
#
#       countryRegionCode       date
# 27368                NO 2022-06-19
# 27369                SE 2022-06-19
# 27370                AR 2022-06-20
# 27371                CO 2022-06-20
# 27372                HR 2022-06-22

# %%
from azureml.opendatasets import Diabetes

diabetes = Diabetes.get_tabular_dataset()
diabetes_df = diabetes.to_pandas_dataframe()

# %%
diabetes_df.describe()
# Out:
#               AGE         SEX         BMI          BP          S1          S2  \
# count  442.000000  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    48.518100    1.468326   26.375792   94.647014  189.140271  115.439140
# std     13.109028    0.499561    4.418122   13.831283   34.608052   30.413081
# min     19.000000    1.000000   18.000000   62.000000   97.000000   41.600000
# 25%     38.250000    1.000000   23.200000   84.000000  164.250000   96.050000
# 50%     50.000000    1.000000   25.700000   93.000000  186.000000  113.000000
# 75%     59.000000    2.000000   29.275000  105.000000  209.750000  134.500000
# max     79.000000    2.000000   42.200000  133.000000  301.000000  242.400000
#
#                S3          S4          S5          S6           Y
# count  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    49.788462    4.070249    4.641411   91.260181  152.133484
# std     12.934202    1.290450    0.522391   11.496335   77.093005
# min     22.000000    2.000000    3.258100   58.000000   25.000000
# 25%     40.250000    3.000000    4.276700   83.250000   87.000000
# 50%     48.000000    4.000000    4.620050   91.000000  140.500000
# 75%     57.750000    5.000000    4.997200   98.000000  211.500000
# max     99.000000    9.090000    6.107000  124.000000  346.000000

# %%
diabetes_df.head(10)
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3    S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.00  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.00  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.00  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.00  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.00  4.2905  80  135
# 5   23    1  22.6   89.0  139   64.8  61.0  2.00  4.1897  68   97
# 6   36    2  22.0   90.0  160   99.6  50.0  3.00  3.9512  82  138
# 7   66    2  26.2  114.0  255  185.0  56.0  4.55  4.2485  92   63
# 8   60    2  32.1   83.0  179  119.4  42.0  4.00  4.4773  94  110
# 9   29    1  30.0   85.0  180   93.4  43.0  4.00  5.3845  88  310
