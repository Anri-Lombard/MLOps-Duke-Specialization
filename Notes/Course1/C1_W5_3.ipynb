# %% [markdown]
# <a href="https://colab.research.google.com/github/Anri-Lombard/MLOps-Duke-Specialization/blob/main/Notes/C1_W5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 21.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 35.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 24.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 27.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 16.4 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset, list_datasets

# %%
available = list_datasets()
print(len(available))
print([i for i in available if '/' not in i])
# Out:
# 42125
# ...

# %%
movie_rationales = load_dataset('movie_rationales')
# Out:
# ...
# Generating test split:   0%|          | 0/199 [00:00<?, ? examples/s]
# Dataset movie_rationales downloaded and prepared to /root/.cache/huggingface/datasets/movie_rationales/default/0.1.0/70ed6b72496c90835e8ee73ebf8d0e49f5ad3aa93f302c8a4b6c886143cfb779. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
movie_rationales
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['review', 'label', 'evidences'],
#         num_rows: 1600
#     })
#     validation: Dataset({
#         features: ['review', 'label', 'evidences'],
#         num_rows: 200
#     })
#     test: Dataset({
#         features: ['review', 'label', 'evidences'],
#         num_rows: 199
#     })
# })

# %%
train = movie_rationales['train']
df = train.to_pandas()
df.describe()
# Out:
#              label
# count  1600.000000
# mean      0.500000
# std       0.500156
# min       0.000000
# 25%       0.000000
# 50%       0.500000
# 75%       1.000000
# max       1.000000

# %%
df.head()
# Out:
#                                               review  ...                                          evidences
# 0  plot : two teen couples go to a church party ,...  ...  [mind - fuck movie, the sad part is, downshift...
# 1  the happy bastard 's quick movie review damn\n...  ...  [it 's pretty much a sunken ship, sutherland i...
# 2  it is movies like these that make a jaded movi...  ...  [the characters and acting is nothing spectacu...
# 3  " quest for camelot " is warner bros . '\nfirs...  ...  [dead on arrival, the characters stink, subpar...
# 4  synopsis : a mentally unstable man undergoing ...  ...  [it is highly derivative and somewhat boring, ...
#
# [5 rows x 3 columns]
